# %%
# daniel_luft-martinez_1.ipynb

# %%
## basic first look at raw primary data scource

# %%
import pandas as pd
import numpy as np

# %%
address = pd.read_csv("panama_papers.nodes.address.csv")
address.head()
# Out:
#     node_id  name                                            address  \
# 0  14000001   NaN       -\t27 ROSEWOOD DRIVE #16-19 SINGAPORE 737920
# 1  14000002   NaN            "Almaly Village" v.5, Almaty Kazakhstan
# 2  14000003   NaN  "Cantonia" South Road St Georges Hill Weybridg...
# 3  14000004   NaN  "CAY-OS" NEW ROAD; ST.SAMPSON; GUERNSEY; CHANN...
# 4  14000005   NaN  "Chirag" Plot No 652; Mwamba Road; Kizingo; Mo...
#
#   country_codes       countries       sourceID  \
# 0           SGP       Singapore  Panama Papers
# 1           KAZ      Kazakhstan  Panama Papers
# 2           GBR  United Kingdom  Panama Papers
# 3           GGY        Guernsey  Panama Papers
# 4           KEN           Kenya  Panama Papers
#
#                                        valid_until  note
# 0  The Panama Papers  data is current through 2015   NaN
# 1  The Panama Papers  data is current through 2015   NaN
# 2  The Panama Papers  data is current through 2015   NaN
# ...

# %%
address['address'] = address['address'].map(lambda x: str(x).replace("\"","").replace("\'",""))

# %%
address.head()
# Out:
#     node_id  name                                            address  \
# 0  14000001   NaN       -\t27 ROSEWOOD DRIVE #16-19 SINGAPORE 737920
# 1  14000002   NaN              Almaly Village v.5, Almaty Kazakhstan
# 2  14000003   NaN  Cantonia South Road St Georges Hill Weybridge,...
# 3  14000004   NaN  CAY-OS NEW ROAD; ST.SAMPSON; GUERNSEY; CHANNEL...
# 4  14000005   NaN  Chirag Plot No 652; Mwamba Road; Kizingo; Momb...
#
#   country_codes       countries       sourceID  \
# 0           SGP       Singapore  Panama Papers
# 1           KAZ      Kazakhstan  Panama Papers
# 2           GBR  United Kingdom  Panama Papers
# 3           GGY        Guernsey  Panama Papers
# 4           KEN           Kenya  Panama Papers
#
#                                        valid_until  note
# 0  The Panama Papers  data is current through 2015   NaN
# 1  The Panama Papers  data is current through 2015   NaN
# 2  The Panama Papers  data is current through 2015   NaN
# ...

# %%
address.to_csv("address.csv")

# %%
officer = pd.read_csv("panama_papers.nodes.officer.csv")
officer.head()
# Out:
#     node_id                  name country_codes    countries       sourceID  \
# 0  12000001            KIM SOO IN           KOR  South Korea  Panama Papers
# 1  12000002             Tian Yuan           CHN        China  Panama Papers
# 2  12000003  GREGORY JOHN SOLOMON           AUS    Australia  Panama Papers
# 3  12000004        MATSUDA MASUMI           JPN        Japan  Panama Papers
# 4  12000005           HO THUY NGA           VNM     Viet Nam  Panama Papers
#
#                                       valid_until note
# 0  The Panama Papers data is current through 2015  NaN
# 1  The Panama Papers data is current through 2015  NaN
# 2  The Panama Papers data is current through 2015  NaN
# 3  The Panama Papers data is current through 2015  NaN
# 4  The Panama Papers data is current through 2015  NaN

# %%
officer.to_csv("officer.csv")

# %%
intermediary = pd.read_csv("panama_papers.nodes.intermediary.csv")
print(intermediary.head())
intermediary.to_csv("intermediary.csv")
# Out:
#     node_id                        name country_codes      countries  \
# 0  11000001     MICHAEL PAPAGEORGE, MR.           ZAF   South Africa
# 1  11000002          CORFIDUCIA ANSTALT           LIE  Liechtenstein
# 2  11000003               DAVID, RONALD           MCO         Monaco
# 3  11000004  DE  BOUTSELIS, JEAN-PIERRE           BEL        Belgium
# 4  11000005    THE LEVANT LAWYERS (TLL)           LBN        Lebanon
#
#       status       sourceID                                      valid_until  \
# 0     ACTIVE  Panama Papers  The Panama Papers  data is current through 2015
# 1     ACTIVE  Panama Papers  The Panama Papers  data is current through 2015
# 2  SUSPENDED  Panama Papers  The Panama Papers  data is current through 2015
# 3  SUSPENDED  Panama Papers  The Panama Papers  data is current through 2015
# 4     ACTIVE  Panama Papers  The Panama Papers  data is current through 2015
#
#   note
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN

# %%
entity = pd.read_csv("panama_papers.nodes.entity.csv")
print(entity.head())
entity.to_csv("entity.csv")
# Out:
# C:\Users\Daniel\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#     node_id                                         name jurisdiction  \
# 0  10000001     TIANSHENG INDUSTRY AND TRADING CO., LTD.          SAM
# 1  10000002  NINGBO SUNRISE ENTERPRISES UNITED CO., LTD.          SAM
# 2  10000003                           HOTFOCUS CO., LTD.          SAM
# 3  10000004              SKY-BLUE GIFTS & TOYS CO., LTD.          SAM
# 4  10000005         FORTUNEMAKER INVESTMENTS CORPORATION          SAM
#
#   jurisdiction_description country_codes  countries incorporation_date  \
# 0                    Samoa           HKG  Hong Kong        23-MAR-2006
# 1                    Samoa           HKG  Hong Kong        27-MAR-2006
# 2                    Samoa           HKG  Hong Kong        10-JAN-2006
# ...

# %%
edges = pd.read_csv("panama_papers.edges.csv")
print(edges)
edges.to_csv("edges.csv")
# Out:
# C:\Users\Daniel\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         START_ID                TYPE    END_ID  \
# 0       10000035  registered_address  14095990
# 1       10000044  registered_address  14091035
# 2       10000055  registered_address  14095990
# 3       10000064  registered_address  14091429
# 4       10000089  registered_address  14098253
# 5       10000091  registered_address  14091429
# 6       10000098  registered_address  14099188
# 7       10000105  registered_address  14095990
# 8       10000109  registered_address  14091429
# 9       10000297  registered_address  14095271
# 10      10000464  registered_address  14099155
# 11      10000507  registered_address  14094124
# 12      10000580  registered_address  14097397
# 13      10000581  registered_address  14092297
# ...

# %%
print(address.head())
print(entity.head())
print(intermediary.head())
print(officer.head())
print(edges.head())
# Out:
#     node_id  name                                            address  \
# 0  14000001   NaN       -\t27 ROSEWOOD DRIVE #16-19 SINGAPORE 737920
# 1  14000002   NaN              Almaly Village v.5, Almaty Kazakhstan
# 2  14000003   NaN  Cantonia South Road St Georges Hill Weybridge,...
# 3  14000004   NaN  CAY-OS NEW ROAD; ST.SAMPSON; GUERNSEY; CHANNEL...
# 4  14000005   NaN  Chirag Plot No 652; Mwamba Road; Kizingo; Momb...
#
#   country_codes       countries       sourceID  \
# 0           SGP       Singapore  Panama Papers
# 1           KAZ      Kazakhstan  Panama Papers
# 2           GBR  United Kingdom  Panama Papers
# 3           GGY        Guernsey  Panama Papers
# 4           KEN           Kenya  Panama Papers
#
#                                        valid_until  note
# 0  The Panama Papers  data is current through 2015   NaN
# 1  The Panama Papers  data is current through 2015   NaN
# 2  The Panama Papers  data is current through 2015   NaN
# ...

# %%
print(address.size)
print(entity.size)
print(intermediary.size)
print(officer.size)
print(edges.size)
# Out:
# 747632
# 3631778
# 112880
# 1668814
# 5392816

# %%
print(address.shape)
print(entity.shape)
print(intermediary.shape)
print(officer.shape)
print(edges.shape)
# Out:
# (93454, 8)
# (213634, 17)
# (14110, 8)
# (238402, 7)
# (674102, 8)
